# %%
# import
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import altair as alt
import warnings
import streamlit as st
from keras.layers import Dense, Activation
from keras.models import Sequential
from tensorflow import keras
from sklearn.cluster import KMeans
# folium
import folium
import folium.plugins as plugins
from streamlit_folium import folium_static

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import string

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file
# %matplotlib inline

# this line makes plots prettier on mac retina screens - if you don't have one it shouldn't do anything
# %config InlineBackend.figure_format = 'retina'


# Style
sns.set_style(style = 'darkgrid')

# %%
# import pandas as pd
# import glob
# import os

# files = os.path.join("/Users/hitomihoshino/Documents/DS/salesforce/global","scrape*.csv")
# files = glob.glob(files)

# df = pd.concat(map(pd.read_csv, files), ignore_index=True)

# df.to_csv('glassdoor_webscraped.csv')

# %%
df = pd.read_csv('glassdoor_webscraped.csv')
df.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'], inplace =True)

# %%
df.rename(columns = {'pros':'Pros', 'cons':'Cons', 'helpful':'Helpful'}, inplace = True)

# %%
df['cons'] = df['Cons']

# %%
df.head()
# Out:
#                                             title  \
# 0                             Great Place To Work
# 1                          Opportunity for Growth
# 2                             Great place to work
# 3  Great culture and great opportunity for growth
# 4                         Fabulous Place to Work!
#
#                                          author_info  rating  \
# 0  May 3, 2021 - Partner Account Manager in Washi...     5.0
# 1  May 3, 2021 - Business Development Representat...     5.0
# 2                   May 3, 2021 - Anonymous Employee     5.0
# 3             May 3, 2021 - BDR in San Francisco, CA     5.0
# 4  May 3, 2021 - Customer Success Guide in Denver...     5.0
#
#                                                 Pros  \
# 0  Leader support, Transparency, Benefits, work/l...
# 1  -Quickly move up -Access to networking with pe...
# 2          High income potential and upward mobility
# 3      Excellent growth and networking opportunities
# 4  Once you’re in, you’re given the freedom and f...
#
#                                                 Cons  \
# 0                     I have not found any cons yet.
# 1  -Large company, there can be a decent amount o...
# 2  Pressure cooker, high expectations and stress ...
# 3                       Not many cons I can think of
# 4  Still a “startup mentality”—so keep in mind al...
#
#                                     Helpful  \
# 0  Be the first to find this review helpful
# 1  Be the first to find this review helpful
# 2  Be the first to find this review helpful
# 3  Be the first to find this review helpful
# 4  Be the first to find this review helpful
#
#                                                 cons
# 0                     I have not found any cons yet.
# 1  -Large company, there can be a decent amount o...
# 2  Pressure cooker, high expectations and stress ...
# 3                       Not many cons I can think of
# 4  Still a “startup mentality”—so keep in mind al...

# %% [markdown]
# # Cons

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 20}

plt.rc('font', **font)

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
from textblob import TextBlob
from textblob import Word
import re,string,unicodedata

# %% [markdown]
# ### Tokenization

# %%
#Tokenization of text
tokenizer=ToktokTokenizer()
#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')

# %% [markdown]
# ### Removing special chars

# %%
#Define function for removing special characters
def remove_special_characters(text, remove_digits=True):
    pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',str(text))
    return text
#Apply function on review column
df['Cons']=df['Cons'].apply(remove_special_characters)

# %% [markdown]
# ### Text stemming

# %%
# #Stemming the text
# def simple_stemmer(text):
#     ps=nltk.porter.PorterStemmer()
#     text= ' '.join([ps.stem(word) for word in text.split()])
#     return text
# #Apply function on review column
# df['Cons']=df['Cons'].apply(simple_stemmer)

# %% [markdown]
# ### Text Lemmatizing

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]


#Apply function on review column
df['Cons']=df['Cons'].apply(lemmatize_text)

# %% [markdown]
# ### Removing stopwords

# %%
#set stopwords to english
stop=set(stopwords.words('english'))
print(stop)

#removing the stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text
#Apply function on review column
df['Cons']=df['Cons'].apply(remove_stopwords)
# Out:
# {'their', 'while', 'about', 'mustn', 'for', 'we', 'have', 'such', 'shan', "it's", "couldn't", 'under', 'during', 'with', 'this', 'out', 'which', 'himself', 'ma', 'or', 'been', 'more', 'but', 're', 'm', 'couldn', 'after', 'don', "wouldn't", 'him', "should've", 'shouldn', 'how', 'in', 'not', 'further', 'he', 'they', 'an', 'both', 'myself', 'do', "didn't", 'all', 'isn', 'can', 'had', 'where', 'ours', "haven't", 'me', 'some', "doesn't", 'd', 'these', 'being', 'did', 'down', 'was', 'up', 'most', "you'd", 'theirs', 'are', 'above', 'hasn', 'now', 'very', 'too', 'so', 'y', 'were', "shan't", 'then', "mustn't", 'she', 'themselves', 'won', 'from', "hadn't", 'weren', 'does', "you've", 'yours', 'his', 'needn', "mightn't", 'through', 'because', 'o', "won't", 'doesn', 'between', 'here', 'against', 'wouldn', 'until', 'itself', 'the', 'on', 'own', 'than', 'doing', 'haven', 'if', 's', 'just', 'am', 'should', 'there', 'at', 'no', "you'll", 't', 'll', 'them', 'any', "aren't", 'her', 'mightn', 'by', "shouldn't", 'and', 'as', "don't", 'aren', "hasn't", "isn't", 'i', "you're", 'ain', 'of', "wasn't", 'that', 'what', 'each', 'other', 'when', 'over', 'it', 'has', 'those', 'once', 've', 'having', 'will', 'is', 'wasn', 'a', 'only', 'before', "needn't", "weren't", 'yourselves', 'be', 'few', 'our', 'off', 'hers', 'yourself', 'to', 'why', 'whom', 'my', 'its', 'didn', 'again', 'into', 'nor', 'your', "she's", 'who', "that'll", 'ourselves', 'below', 'same', 'hadn', 'you', 'herself'}

# %%
df.head()
# Out:
#                                             title  \
# 0                             Great Place To Work
# 1                          Opportunity for Growth
# 2                             Great place to work
# 3  Great culture and great opportunity for growth
# 4                         Fabulous Place to Work!
#
#                                          author_info  rating  \
# 0  May 3, 2021 - Partner Account Manager in Washi...     5.0
# 1  May 3, 2021 - Business Development Representat...     5.0
# 2                   May 3, 2021 - Anonymous Employee     5.0
# 3             May 3, 2021 - BDR in San Francisco, CA     5.0
# 4  May 3, 2021 - Customer Success Guide in Denver...     5.0
#
#                                                 Pros  \
# 0  Leader support, Transparency, Benefits, work/l...
# 1  -Quickly move up -Access to networking with pe...
# 2          High income potential and upward mobility
# 3      Excellent growth and networking opportunities
# 4  Once you’re in, you’re given the freedom and f...
#
#                                                 Cons  \
# 0  [ ' ' , ' ' , ' ' , ' found ' , ' ' , ' con ' ...
# 1  [ ' Large ' , ' company ' , ' ' , ' ' , ' ' , ...
# 2  [ ' Pressure ' , ' cooker ' , ' high ' , ' exp...
# 3  [ ' ' , ' many ' , ' con ' , ' ' , ' ' , ' thi...
# 4  [ ' Still ' , ' ' , ' startup ' , ' mentalitys...
#
#                                     Helpful  \
# 0  Be the first to find this review helpful
# 1  Be the first to find this review helpful
# 2  Be the first to find this review helpful
# 3  Be the first to find this review helpful
# 4  Be the first to find this review helpful
#
#                                                 cons
# 0                     I have not found any cons yet.
# 1  -Large company, there can be a decent amount o...
# 2  Pressure cooker, high expectations and stress ...
# 3                       Not many cons I can think of
# 4  Still a “startup mentality”—so keep in mind al...

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3)
tf.fit(df['Cons'])

pro_tf = tf.transform(df['Cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())



fig, ax = plt.subplots(figsize = (30,30))
top_texts = pro_df.sum().sort_values(ascending=False)
top_texts.head(50).plot(kind='barh')
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(2160x2160)

# %%
fig, ax = plt.subplots(1,1)
# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# Figure(432x288)

# %% [markdown]
# ### Bigram

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range=(2,2))
tf.fit(df['Cons'])

pro_tf = tf.transform(df['Cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())



fig, ax = plt.subplots(figsize = (20,20))
top_texts = pro_df.sum().sort_values(ascending=False)
top_texts.head(50).plot(kind='barh')
print(fig)

fig, ax = plt.subplots()
# Create and generate a word cloud image:
Cloud = WordCloud(width=500, height=400,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts)

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")

print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(1440x1440)
# Figure(432x288)

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range=(3,3))
tf.fit(df['Cons'])

pro_tf = tf.transform(df['Cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())



fig, ax = plt.subplots(figsize = (20,20))
top_texts = pro_df.sum().sort_values(ascending=False)
top_texts.head(50).plot(kind='barh')
print(fig)

fig, ax = plt.subplots()
# Create and generate a word cloud image:
Cloud = WordCloud(width=500, height=400,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts)

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(1440x1440)
# Figure(432x288)

# %%
df.head()
# Out:
#                                             title  \
# 0                             Great Place To Work
# 1                          Opportunity for Growth
# 2                             Great place to work
# 3  Great culture and great opportunity for growth
# 4                         Fabulous Place to Work!
#
#                                          author_info  rating  \
# 0  May 3, 2021 - Partner Account Manager in Washi...     5.0
# 1  May 3, 2021 - Business Development Representat...     5.0
# 2                   May 3, 2021 - Anonymous Employee     5.0
# 3             May 3, 2021 - BDR in San Francisco, CA     5.0
# 4  May 3, 2021 - Customer Success Guide in Denver...     5.0
#
#                                                 Pros  \
# 0  Leader support, Transparency, Benefits, work/l...
# 1  -Quickly move up -Access to networking with pe...
# 2          High income potential and upward mobility
# 3      Excellent growth and networking opportunities
# 4  Once you’re in, you’re given the freedom and f...
#
#                                                 Cons  \
# 0  [ ' ' , ' ' , ' ' , ' found ' , ' ' , ' con ' ...
# 1  [ ' Large ' , ' company ' , ' ' , ' ' , ' ' , ...
# 2  [ ' Pressure ' , ' cooker ' , ' high ' , ' exp...
# 3  [ ' ' , ' many ' , ' con ' , ' ' , ' ' , ' thi...
# 4  [ ' Still ' , ' ' , ' startup ' , ' mentalitys...
#
#                                     Helpful  \
# 0  Be the first to find this review helpful
# 1  Be the first to find this review helpful
# 2  Be the first to find this review helpful
# 3  Be the first to find this review helpful
# 4  Be the first to find this review helpful
#
#                                                 cons
# 0                     I have not found any cons yet.
# 1  -Large company, there can be a decent amount o...
# 2  Pressure cooker, high expectations and stress ...
# 3                       Not many cons I can think of
# 4  Still a “startup mentality”—so keep in mind al...

# %% [markdown]
# work life balance (忙しすぎてバランスがない？、difficultっていう言葉もあったから難しい？)
#
# great (best) place work (比較なのかな)
#
# long term relationship (誰と誰の関係性が悪いの？、客と従業員、従業員と従業員)
#
# salesforce great (large) company (小さいといいのか？、小さいと情報をよりキャッチしやすい)
#
# downside working salesforce (SFの仕事が単調、他の企業に比べて仕事が弱い)
#
# big company (世界のいろんなところにオフィスがあるのがだめ？)
#
# middle management (ミドルマネジメントの対応が悪い？、なりにくい)
#
# internal politics (多種多様性がない？、日本ではかなり推進されているけど外国だとまだ差別などを感じる？)
#
# career growth  (promotionが遅い？)
#
# management (マネジメントが行き届いていない？雑い？)

# %%
def strings(words = []):
    base = r'^{}'
    expr = '(?=.*{})'
    # words = ['apple', 'banana', 'cat']  # example
    strings = base.format(''.join(expr.format(w) for w in words))
    return strings

# %%
def create_folder(strings):
    data = df[df['cons'].str.contains(strings, na=False)]
    data = data['cons']
    return data.to_csv(strings)

# %%
# create_folder(strings(['work', 'life', 'balance']))
# create_folder(strings(['best', 'place', 'work']))
# create_folder(strings(['long', 'term', 'relationship']))
# create_folder(strings(['salesforce', 'large', 'company']))
# create_folder(strings(['downside', 'working', 'salesforce' ]))
# create_folder(strings(['big', 'company']))
# create_folder(strings(['middle', 'management']))
# create_folder(strings(['internal', 'politics']))
# create_folder(strings(['career', 'growth']))
# create_folder(strings(['management']))
# # create_folder(strings([]))

# %% [markdown]
# NLP_cons
#
# ・time promotion (Bigram 1200)
#
# ・bad working (Bi 700)
#
# ・new recruitment (Bi 500)
#
# ・recruitment world fastpaced(Trigram 500)
#
# ・mean big work (Tri 500)

# %%
# create_folder(strings(['time', 'promotion']))
# create_folder(strings(['bad', 'working']))
# create_folder(strings(['new', 'recruitment']))
# create_folder(strings(['recruitment', 'world', 'fastpaced']))
# create_folder(strings(['mean', 'big', 'work']))

# %%
# create_folder(strings(['Trust']))
# create_folder(strings(['Innovation']))
# create_folder(strings(['Customer success']))
# create_folder(strings(['Equality']))
# create_folder(strings(['Sustainability']))
