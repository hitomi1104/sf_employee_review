# %%
# import
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import altair as alt
import warnings
import streamlit as st
import string

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file
# %matplotlib inline

# this line makes plots prettier on mac retina screens - if you don't have one it shouldn't do anything
# %config InlineBackend.figure_format = 'retina'


# Style
sns.set_style(style = 'darkgrid')

# %%
df = pd.read_csv('prod_review.csv')

# %%
df.drop(columns = ['small', 'ui1', 'small1', 'tiptextwrap','small2','ui3',
                   'review-copy-container2',
                   'review-copy-container4',
                  'small3', 'review-profile-defined', 
                   'score-description', 'score-description1'], inplace = True)

# %%
df.columns
# Out:
# Index(['ui', 'ui2', 'review-copy-container', 'review-date',
#        'review-copy-container1', 'review-copy-container3',
#        'review-copy-container5', 'ui4', 'review-copy-sub-header'],
#       dtype='object')

# %%
df
# Out:
#                                         ui                            ui2  \
# 0          Company size: 11 - 50 employees       Review Source:  Capterra
# 1                        Verified reviewer    Industry: Computer Software
# 2                        Verified reviewer    Industry: Computer Software
# 3            Company size: 11-50 employees       Review Source:  Capterra
# 4      Company size: 1,001-5,000 employees       Review Source:  Capterra
# ...                                    ...                            ...
# 9995              Company size: 1 employee  Time used: Less than 6 months
# 9996  Company size: 5,001-10,000 employees   Time used: Less than 2 years
# 9997        Company size: 51-200 employees  Time used: Less than 6 months
# 9998              Company size: 1 employee  Time used: Less than 6 months
# 9999                     Verified reviewer         Industry: Construction
#
#                                   review-copy-container    review-date  \
# ...
