# %%
# import
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import altair as alt
import warnings
import streamlit as st
from keras.layers import Dense, Activation
from keras.models import Sequential
from tensorflow import keras
from sklearn.cluster import KMeans
import warnings


# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import string

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file
# %matplotlib inline

# this line makes plots prettier on mac retina screens - if you don't have one it shouldn't do anything
# %config InlineBackend.figure_format = 'retina'


# Style
sns.set_style(style = 'darkgrid')

# %%
df = pd.read_csv('nlp.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'rating', 'pros', 'rating.1', 'cons', 'pros_nlp',
#        'cons_nlp', 'emotion+', 'sentiment+', 'emotion-', 'sentiment-'],
#       dtype='object')

# %%
df.drop(columns = ['rating', 'Unnamed: 0', 'rating.1', 'pros_nlp',
       'cons_nlp'], inplace = True)

# %%
df
# Out:
#                                                     pros  \
# 0      Working Hours/Holidays/Holidays: It's up to yo...
# 1      Corporate culture/corporate culture: The compa...
# 2      Corporate culture/corporate culture: I feel th...
# 3      Office environment: We moved to a new office f...
# 4      Working hours/holidays/holidays/holidays/holid...
# ...                                                  ...
# 10343  Great team members and collaboration, excellen...
# 10344  - PEOPL E: Talents pool and International Grow...
# 10345              Good benefits, good solutions to sell
# 10346  - Amazing people you get to work closely with ...
# 10347  Great work place. Work-life balance is really ...
#
#                                                     cons emotion+ sentiment+  \
# 0      Working Hours/Holidays/Holidays: It's up to yo...      joy        pos
# 1      Salary system: 80% of the estimated annual inc...      joy        pos
# 2      Welfare: There is a good cafeteria in the offi...      joy        pos
# 3      Working Hours/Holiday Leave: Work-life balance...      joy        pos
# 4      Working Hours/Holidays/Holidays: It's up to yo...      joy        pos
# ...                                                  ...      ...        ...
# 10343                                                NaN      joy        pos
# 10344                                                NaN      joy        pos
# 10345                                                NaN      joy        pos
# 10346                                                NaN      joy        pos
# 10347                                                NaN      joy        pos
#
#        emotion- sentiment-
# 0           joy        neg
# 1           joy        neg
# 2           joy        neg
# 3           joy        neg
# 4           joy        neg
# ...         ...        ...
# 10343  surprise        neg
# 10344  surprise        neg
# 10345  surprise        neg
# 10346  surprise        neg
# 10347  surprise        neg
#
# [10348 rows x 6 columns]

# %%
# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import string


from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
from textblob import TextBlob
from textblob import Word
import re,string,unicodedata

# %%
#Tokenization of text
tokenizer=ToktokTokenizer()
#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')

# %%
#Define function for removing special characters
def remove_special_characters(text, remove_digits=True):
    pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',str(text))
    return text
#Apply function on review column
df['pros']=df['pros'].apply(remove_special_characters)
df['cons']=df['cons'].apply(remove_special_characters)

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]


#Apply function on review column
df['pros']=df['pros'].apply(lemmatize_text)
df['cons']=df['cons'].apply(lemmatize_text)

# %%
#set stopwords to english
stop=set(stopwords.words('english'))
print(stop)

#removing the stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text
#Apply function on review column
df['pros']=df['pros'].apply(remove_stopwords)
df['cons']=df['cons'].apply(remove_stopwords)
# Out:
# {"you'd", 'him', 'now', 'or', 'these', 'll', 's', 'their', 'over', 'having', 'them', 'off', "hadn't", 'until', 'above', 'won', 'you', 'all', 'does', 'about', 'wasn', 'just', 'on', 'to', 'can', 'while', 'other', 'doing', 'theirs', 'my', 'themselves', 'are', 'under', 'how', 'below', "you'll", 'any', 't', 'nor', 'before', 'why', 'wouldn', "needn't", 'her', 'down', 'very', 'himself', 'not', 'but', "mustn't", 'needn', 'most', 'been', 'couldn', 'your', 'his', "you're", 'mightn', 'and', 'for', 'too', "wouldn't", 'hers', 'some', 'herself', 'here', 'i', 'will', 'doesn', 'by', 'didn', 'both', 'ain', 'yours', 'more', 'shan', "weren't", 'own', 'whom', 'from', "don't", 'our', "you've", 'if', 'with', 'few', 'yourselves', 'o', 'm', 'he', 'such', 'should', 'during', 're', "doesn't", 'shouldn', 'don', 'as', 'hasn', "shouldn't", 'same', 'were', 'ourselves', 'there', 'has', 'those', 'do', 've', 'out', 'what', 'so', 'than', 'against', "mightn't", "couldn't", 'a', 'because', 'no', 'haven', 'itself', 'through', 'hadn', "won't", 'me', 'they', 'we', "aren't", "should've", 'into', 'that', 'the', 'be', 'isn', 'aren', "isn't", 'was', 'y', 'have', 'then', "she's", 'weren', 'it', 'did', 'is', 'again', 'in', 'which', 'up', 'each', 'only', "haven't", 'mustn', 'between', 'its', "shan't", 'who', 'myself', 'had', "that'll", 'of', 'at', 'ours', 'further', 'where', 'she', "hasn't", 'once', 'an', "it's", "wasn't", 'am', "didn't", 'yourself', 'd', 'when', 'this', 'being', 'after', 'ma'}

# %%
df
# Out:
#                                                     pros  \
# 0      [ ' Working ' , ' HoursHolidaysHolidays ' , ' ...
# 1      [ ' Corporate ' , ' culturecorporate ' , ' cul...
# 2      [ ' Corporate ' , ' culturecorporate ' , ' cul...
# 3      [ ' Office ' , ' environment ' , ' ' , ' moved...
# 4      [ ' Working ' , ' hoursholidaysholidaysholiday...
# ...                                                  ...
# 10343  [ ' Great ' , ' team ' , ' member ' , ' ' , ' ...
# 10344  [ ' PEOPL ' , ' E ' , ' Talents ' , ' pool ' ,...
# 10345  [ ' Good ' , ' benefit ' , ' good ' , ' soluti...
# 10346  [ ' Amazing ' , ' people ' , ' ' , ' get ' , '...
# 10347  [ ' Great ' , ' work ' , ' place ' , ' Worklif...
#
#                                                     cons emotion+ sentiment+  \
# 0      [ ' Working ' , ' HoursHolidaysHolidays ' , ' ...      joy        pos
# 1      [ ' Salary ' , ' system ' , ' 80 ' , ' ' , ' '...      joy        pos
# 2      [ ' Welfare ' , ' ' , ' ' , ' ' , ' good ' , '...      joy        pos
# 3      [ ' Working ' , ' HoursHoliday ' , ' Leave ' ,...      joy        pos
# 4      [ ' Working ' , ' HoursHolidaysHolidays ' , ' ...      joy        pos
# ...                                                  ...      ...        ...
# 10343                                        [ ' nan ' ]      joy        pos
# 10344                                        [ ' nan ' ]      joy        pos
# 10345                                        [ ' nan ' ]      joy        pos
# 10346                                        [ ' nan ' ]      joy        pos
# 10347                                        [ ' nan ' ]      joy        pos
#
#        emotion- sentiment-
# 0           joy        neg
# 1           joy        neg
# 2           joy        neg
# 3           joy        neg
# 4           joy        neg
# ...         ...        ...
# 10343  surprise        neg
# 10344  surprise        neg
# 10345  surprise        neg
# 10346  surprise        neg
# 10347  surprise        neg
#
# [10348 rows x 6 columns]

# %% [markdown]
# # Cons
# ### joy

# %%
pos_joy = df[(df['sentiment-'] == 'pos') & (df['emotion-'] == 'joy')]
neu_joy = df[(df['sentiment-'] == 'neutral') & (df['emotion-'] == 'joy')]
neg_joy = df[(df['sentiment-'] == 'neg') & (df['emotion-'] == 'joy')]

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(pos_joy['cons'])

pro_tf = tf.transform(pos_joy['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())




top_texts = pro_df.sum().sort_values(ascending=False)

fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neu_joy['cons'])

pro_tf = tf.transform(neu_joy['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())




top_texts = pro_df.sum().sort_values(ascending=False)

fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neg_joy['cons'])

pro_tf = tf.transform(neg_joy['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())




top_texts = pro_df.sum().sort_values(ascending=False)

fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %% [markdown]
# ### Surprise

# %%
pos_sur = df[(df['sentiment-'] == 'pos') & (df['emotion-'] == 'surprise')]
neu_sur = df[(df['sentiment-'] == 'neutral') & (df['emotion-'] == 'surprise')]
neg_sur = df[(df['sentiment-'] == 'neg') & (df['emotion-'] == 'surprise')]

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(pos_sur['cons'])
pro_tf = tf.transform(pos_sur['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neu_sur['cons'])
pro_tf = tf.transform(neu_sur['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       1 tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
# ----> 2 tf.fit(neu_sur['cons'])
#       3 pro_tf = tf.transform(neu_sur['cons'])
#       4 pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:2053, in TfidfVectorizer.fit(self, raw_documents, y)
#    2051 self._check_params()
#    2052 self._warn_for_unused_params()
# -> 2053 X = super().fit_transform(raw_documents)
#    2054 self._tfidf.fit(X)
#    2055 return self
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1347, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1345 if max_features is not None:
#    1346     X = self._sort_features(X, vocabulary)
# -> 1347 X, self.stop_words_ = self._limit_features(
#    1348     X, vocabulary, max_doc_count, min_doc_count, max_features
#    1349 )
#    1350 if max_features is None:
#    1351     X = self._sort_features(X, vocabulary)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1179, in CountVectorizer._limit_features(self, X, vocabulary, high, low, limit)
#    1177 kept_indices = np.where(mask)[0]
#    1178 if len(kept_indices) == 0:
# -> 1179     raise ValueError(
#    1180         "After pruning, no terms remain. Try a lower min_df or a higher max_df."
#    1181     )
#    1182 return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neg_sur['cons'])
pro_tf = tf.transform(neg_sur['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %% [markdown]
# ## sadness

# %%
pos_sadness = df[(df['sentiment-'] == 'pos') & (df['emotion-'] == 'sadness')]
neu_sadness = df[(df['sentiment-'] == 'neutral') & (df['emotion-'] == 'sadness')]
neg_sadness = df[(df['sentiment-'] == 'neg') & (df['emotion-'] == 'sadness')]

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(pos_sadness['cons'])
pro_tf = tf.transform(pos_sadness['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neu_sadness['cons'])
pro_tf = tf.transform(neu_sadness['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
# ----> 2 tf.fit(neu_sadness['cons'])
#       3 pro_tf = tf.transform(neu_sadness['cons'])
#       4 pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:2053, in TfidfVectorizer.fit(self, raw_documents, y)
#    2051 self._check_params()
#    2052 self._warn_for_unused_params()
# -> 2053 X = super().fit_transform(raw_documents)
#    2054 self._tfidf.fit(X)
#    2055 return self
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1347, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1345 if max_features is not None:
#    1346     X = self._sort_features(X, vocabulary)
# -> 1347 X, self.stop_words_ = self._limit_features(
#    1348     X, vocabulary, max_doc_count, min_doc_count, max_features
#    1349 )
#    1350 if max_features is None:
#    1351     X = self._sort_features(X, vocabulary)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1179, in CountVectorizer._limit_features(self, X, vocabulary, high, low, limit)
#    1177 kept_indices = np.where(mask)[0]
#    1178 if len(kept_indices) == 0:
# -> 1179     raise ValueError(
#    1180         "After pruning, no terms remain. Try a lower min_df or a higher max_df."
#    1181     )
#    1182 return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neg_sadness['cons'])
pro_tf = tf.transform(neg_sadness['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %% [markdown]
# #### Fear

# %%
pos_fear = df[(df['sentiment+'] == 'pos') & (df['emotion-'] == 'fear')]
neu_fear = df[(df['sentiment+'] == 'neutral') & (df['emotion-'] == 'fear')]
neg_fear = df[(df['sentiment+'] == 'neg') & (df['emotion-'] == 'fear')]

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(pos_fear['cons'])
pro_tf = tf.transform(pos_fear['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neu_fear['cons'])
pro_tf = tf.transform(neu_fear['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 2>()
#       1 tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
# ----> 2 tf.fit(neu_fear['cons'])
#       3 pro_tf = tf.transform(neu_fear['cons'])
#       4 pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:2053, in TfidfVectorizer.fit(self, raw_documents, y)
#    2051 self._check_params()
#    2052 self._warn_for_unused_params()
# -> 2053 X = super().fit_transform(raw_documents)
#    2054 self._tfidf.fit(X)
#    2055 return self
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1347, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1345 if max_features is not None:
#    1346     X = self._sort_features(X, vocabulary)
# -> 1347 X, self.stop_words_ = self._limit_features(
#    1348     X, vocabulary, max_doc_count, min_doc_count, max_features
#    1349 )
#    1350 if max_features is None:
#    1351     X = self._sort_features(X, vocabulary)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:1179, in CountVectorizer._limit_features(self, X, vocabulary, high, low, limit)
#    1177 kept_indices = np.where(mask)[0]
#    1178 if len(kept_indices) == 0:
# -> 1179     raise ValueError(
#    1180         "After pruning, no terms remain. Try a lower min_df or a higher max_df."
#    1181     )
#    1182 return X[:, kept_indices], removed_terms
#
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(neg_fear['cons'])
pro_tf = tf.transform(neg_fear['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())


top_texts = pro_df.sum().sort_values(ascending=False)
fig, ax = plt.subplots(1,1)

# Create and generate a word cloud image:
Cloud = WordCloud(width=1000, height=700,
                  background_color='black',
                  stopwords=stopwords,
                  min_font_size=3,
                  min_word_length=0).generate_from_frequencies(top_texts.head(100))

# background_color="white", max_words=50).generate_from_frequencies(top_texts)

# Display the generated image:
# plt.figure(figsize=(15,10))
plt.imshow(Cloud, interpolation='bilinear')
plt.axis("off")
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(432x288)
