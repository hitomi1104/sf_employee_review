# %%
# import
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import altair as alt
import warnings
import streamlit as st
from keras.layers import Dense, Activation
from keras.models import Sequential
from tensorflow import keras
from sklearn.cluster import KMeans


# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import string

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file
# %matplotlib inline

# this line makes plots prettier on mac retina screens - if you don't have one it shouldn't do anything
# %config InlineBackend.figure_format = 'retina'


# Style
sns.set_style(style = 'darkgrid')

# %%
df = pd.read_csv("glassdoor_webscraped.csv")
df2 = pd.read_csv('review_jp_nlp.csv')

# %%
df2.rename(columns = {'reviwe_translated_original': 'review_translated_original'}, inplace = True)

# %%
df = df.loc[:, 'rating':'cons']
df2 = df2.loc[:, 'rating':'emotion']

# %%
neg = df2[df2['sentiment'] == 'neg']
pos = df2[df2['sentiment'] == 'pos']

# %%
neg = neg[['rating', 'review_translated_original']]
pos = pos[['rating', 'review_translated_original']]

# %%
pos1 = df.loc[:, 'rating':'pros']
neg1 = df[['rating', 'cons']]

# %%
pos.columns = pos1.columns
neg.columns = neg1.columns

# %%
df_p = pos.append(pos1, ignore_index = True)
df_n = neg.append(neg1, ignore_index = True)

# %%
df
# Out:
#        rating                                               pros  rating  \
# 0         4.7  Working Hours/Holidays/Holidays: It's up to yo...     4.7
# 1         4.9  Corporate culture/corporate culture: The compa...     5.0
# 2         5.0  Corporate culture/corporate culture: I feel th...     5.0
# 3         3.8  Office environment: We moved to a new office f...     2.8
# 4         4.5  Working hours/holidays/holidays/holidays/holid...     4.7
# ...       ...                                                ...     ...
# 10343     4.0  Great team members and collaboration, excellen...     NaN
# 10344     3.0  - PEOPL E: Talents pool and International Grow...     NaN
# 10345     3.0              Good benefits, good solutions to sell     NaN
# 10346     5.0  - Amazing people you get to work closely with ...     NaN
# 10347     5.0  Great work place. Work-life balance is really ...     NaN
#
#                                                     cons  \
# 0      Working Hours/Holidays/Holidays: It's up to yo...
# 1      Salary system: 80% of the estimated annual inc...
# 2      Welfare: There is a good cafeteria in the offi...
# 3      Working Hours/Holiday Leave: Work-life balance...
# 4      Working Hours/Holidays/Holidays: It's up to yo...
# ...                                                  ...
# 10343                                                NaN
# 10344                                                NaN
# 10345                                                NaN
# 10346                                                NaN
# 10347                                                NaN
#
#                                                 pros_nlp  \
# 0      [ ' working ' , ' hoursholidaysholidays ' , ' ...
# 1      [ ' corporate ' , ' culturecorporate ' , ' cul...
# 2      [ ' corporate ' , ' culturecorporate ' , ' cul...
# 3      [ ' office ' , ' environment ' , ' ' , ' moved...
# 4      [ ' working ' , ' hoursholidaysholidaysholiday...
# ...                                                  ...
# 10343  [ ' great ' , ' team ' , ' member ' , ' ' , ' ...
# 10344  [ ' peopl ' , ' e ' , ' talent ' , ' pool ' , ...
# 10345  [ ' good ' , ' benefit ' , ' good ' , ' soluti...
# 10346  [ ' amazing ' , ' people ' , ' ' , ' get ' , '...
# 10347  [ ' great ' , ' work ' , ' place ' , ' worklif...
#
#                                                 cons_nlp
# 0      [ ' working ' , ' hoursholidaysholidays ' , ' ...
# 1      [ ' salary ' , ' system ' , ' 80 ' , ' ' , ' '...
# 2      [ ' welfare ' , ' ' , ' ' , ' ' , ' good ' , '...
# 3      [ ' working ' , ' hoursholiday ' , ' leave ' ,...
# 4      [ ' working ' , ' hoursholidaysholidays ' , ' ...
# ...                                                  ...
# 10343                                                NaN
# 10344                                                NaN
# 10345                                                NaN
# 10346                                                NaN
# 10347                                                NaN
#
# [10348 rows x 6 columns]

# %%
df_p.to_csv('global_positive.csv')
df_n.to_csv('global_negative.csv')

# %%
df_p.dropna(inplace = True)
df_n.dropna(inplace = True)

# %%
df_p
# Out:
#        rating                                               pros
# 0         4.7  Working Hours/Holidays/Holidays: It's up to yo...
# 1         4.9  Corporate culture/corporate culture: The compa...
# 2         5.0  Corporate culture/corporate culture: I feel th...
# 3         3.8  Office environment: We moved to a new office f...
# 4         4.5  Working hours/holidays/holidays/holidays/holid...
# ...       ...                                                ...
# 10343     4.0  Great team members and collaboration, excellen...
# 10344     3.0  - PEOPL E: Talents pool and International Grow...
# 10345     3.0              Good benefits, good solutions to sell
# 10346     5.0  - Amazing people you get to work closely with ...
# 10347     5.0  Great work place. Work-life balance is really ...
#
# [10347 rows x 2 columns]

# %%
# NLP
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
import string

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
from textblob import TextBlob
from textblob import Word
import re,string,unicodedata

# %%
df_p['pros'] = df_p['pros'].str.lower()
df_n['cons'] = df_n['cons'].str.lower()

# %%
#Tokenization of text
tokenizer=ToktokTokenizer()
#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')

# %%
#Define function for removing special characters
def remove_special_characters(text, remove_digits=True):
    pattern=r'[^a-zA-z0-9\s]'
    text=re.sub(pattern,'',str(text))
    return text
#Apply function on review column
df_p['pros']=df_p['pros'].apply(remove_special_characters)
df_n['cons']=df_n['cons'].apply(remove_special_characters)

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]


#Apply function on review column
df_p['pros']=df_p['pros'].apply(lemmatize_text)
df_n['cons']=df_n['cons'].apply(lemmatize_text)

# %%
#set stopwords to english
stop=set(stopwords.words('english'))
print(stop)

#removing the stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

#Apply function on review column
df_p['pros']=df_p['pros'].apply(remove_stopwords)
df_n['cons']=df_n['cons'].apply(remove_stopwords)
# Out:
# {'shan', 'ours', "you'll", 'an', 'you', 'nor', "weren't", 'when', 'do', "isn't", 'just', 'about', "it's", 'their', 'each', "mustn't", 'he', 'y', 'had', 'mightn', 'weren', 'while', 'doesn', 'and', "couldn't", 'how', 'no', "you'd", 'them', 'having', 'off', 'we', 'so', 'were', "didn't", 'then', 'a', 'below', 'hadn', 'haven', 't', 'yours', 'some', 'those', 'before', 'my', 'is', 'up', 'itself', 'from', 'both', 'than', "you're", 'to', 'not', 'which', 'himself', 'on', 're', 'further', "she's", "aren't", 'any', 'very', 'd', 'didn', 'ourselves', 'too', 'here', 've', "shouldn't", 'that', 'me', 'does', 'if', 'as', 'they', 'for', 'down', 'o', 'wasn', 'by', 'under', 'with', 'but', 'or', "won't", "that'll", 'her', 'between', 'own', "wasn't", 'won', 'needn', 'be', "don't", 'its', "wouldn't", 'these', 'once', "doesn't", 'hasn', 'such', "hadn't", 'ain', 'this', 'all', 'couldn', 'where', 'whom', 'out', 'his', 'll', 'am', 'over', "shan't", 'wouldn', "mightn't", 'isn', 'myself', 'can', 'other', "needn't", 'above', 'until', 'did', "you've", 'are', 'into', 'was', 'again', 'will', 'yourself', 'most', 'ma', 'yourselves', 'him', 'of', 's', 'doing', 'aren', 'at', 'our', 'same', 'against', 'after', 'in', 'has', 'who', 'don', "should've", 'it', 'themselves', 'only', 'mustn', 'because', 'shouldn', 'i', 'during', 'what', 'hers', 'being', 'more', "hasn't", 'your', 'there', 'been', 'herself', 'theirs', 'have', 'through', 'few', 'should', 'm', 'why', 'she', 'the', 'now', "haven't"}

# %% [markdown]
# ### TF-IDF vect (Term Frequency Inverse Document Frequency)
#
# tf-idf consider overall documents of weight of words.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_p.pros
# Out:
# 0        [ ' working ' , ' hoursholidaysholidays ' , ' ...
# 1        [ ' corporate ' , ' culturecorporate ' , ' cul...
# 2        [ ' corporate ' , ' culturecorporate ' , ' cul...
# 3        [ ' office ' , ' environment ' , ' ' , ' moved...
# 4        [ ' working ' , ' hoursholidaysholidaysholiday...
#                                ...
# 10343    [ ' great ' , ' team ' , ' member ' , ' ' , ' ...
# 10344    [ ' peopl ' , ' e ' , ' talent ' , ' pool ' , ...
# 10345    [ ' good ' , ' benefit ' , ' good ' , ' soluti...
# 10346    [ ' amazing ' , ' people ' , ' ' , ' get ' , '...
# 10347    [ ' great ' , ' work ' , ' place ' , ' worklif...
# Name: pros, Length: 10347, dtype: object

# %% [markdown]
# ### Bi&Trigram
# #### Pros

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(df_p['pros'])

pro_tf = tf.transform(df_p['pros'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())



fig, ax = plt.subplots(figsize = (15,15))
top_texts = pro_df.sum().sort_values(ascending=False)
top_texts.head(80).plot(kind='barh')
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(1080x1080)

# %% [markdown]
# #### Cons

# %%
tf = TfidfVectorizer(stop_words='english', min_df=3, ngram_range = (2,3))
tf.fit(df_n['cons'])

pro_tf = tf.transform(df_n['cons'])
pro_df = pd.DataFrame(pro_tf.todense(), columns=tf.get_feature_names())



fig, ax = plt.subplots(figsize = (15,15))
top_texts = pro_df.sum().sort_values(ascending=False)
top_texts.head(80).plot(kind='barh')
print(fig)
# Out:
# /Users/hitomihoshino/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Figure(1080x1080)

# %%
df['pros_nlp'] = df_p['pros']
df['cons_nlp'] = df_n['cons']

# %%
df.head()
# Out:
#    rating                                               pros  rating  \
# 0     4.7  Working Hours/Holidays/Holidays: It's up to yo...     4.7
# 1     4.9  Corporate culture/corporate culture: The compa...     5.0
# 2     5.0  Corporate culture/corporate culture: I feel th...     5.0
# 3     3.8  Office environment: We moved to a new office f...     2.8
# 4     4.5  Working hours/holidays/holidays/holidays/holid...     4.7
#
#                                                 cons  \
# 0  Working Hours/Holidays/Holidays: It's up to yo...
# 1  Salary system: 80% of the estimated annual inc...
# 2  Welfare: There is a good cafeteria in the offi...
# 3  Working Hours/Holiday Leave: Work-life balance...
# 4  Working Hours/Holidays/Holidays: It's up to yo...
#
#                                             pros_nlp  \
# 0  [ ' working ' , ' hoursholidaysholidays ' , ' ...
# 1  [ ' corporate ' , ' culturecorporate ' , ' cul...
# 2  [ ' corporate ' , ' culturecorporate ' , ' cul...
# 3  [ ' office ' , ' environment ' , ' ' , ' moved...
# 4  [ ' working ' , ' hoursholidaysholidaysholiday...
#
#                                             cons_nlp
# 0  [ ' working ' , ' hoursholidaysholidays ' , ' ...
# 1  [ ' salary ' , ' system ' , ' 80 ' , ' ' , ' '...
# 2  [ ' welfare ' , ' ' , ' ' , ' ' , ' good ' , '...
# 3  [ ' working ' , ' hoursholiday ' , ' leave ' ,...
# 4  [ ' working ' , ' hoursholidaysholidays ' , ' ...

# %%
df = pd.concat([df_p, df_n], axis = 1)

# %%
df.to_csv('combined.csv')
