# %%
# import
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import altair as alt
import warnings

# %%
df = pd.read_csv('data_cleaned_translated.csv')

# %%
df.shape
# Out:
# (241, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'topic', 'usage situation', 'type of business',
#        'review date', 'overall rating', 'review', 'number of accounts used',
#        'effects after introducing the service', 'rate ease of use',
#        'rate helpfulness', 'rate customizability',
#        'rate functional satisfaction', 'rate service stability'],
#       dtype='object')

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)
df.head()
# Out:
#                                                topic usage situation  \
# 0                      Great job on customer support           using
# 1      You can share customer management in one app.           using
# 2  If you do not spend time consulting at the tim...           using
# 3                      Customer management made easy           using
# 4       Interdepartmental links can be made stronger           using
#
#                     type of business review date  overall rating  \
# 0                 Consulting Service  2022-07-28               4
# 1                 IT related Service  2022-07-28               5
# 2           Food and Leisure Service  2022-07-22               3
# 3                 IT related Service  2022-07-20               4
# 4  Manufacturer/manufacturing system  2022-07-19               5
#
#                                               review number of accounts used  \
# 0  You can manage the history of previous interac...                >201-300
# 1  By collectively managing internal customer inf...                 >51-100
# 2  Consultation at the time of introduction is th...                 >51-100
# 3  With this service, you can manage customer inf...                      >1
# 4  Salesforce Sales Cloud has a very easy-to-read...                    2-10
#
#                effects after introducing the service  rate ease of use  \
# 0  In the past, sales management and personnel ma...               4.0
# 1  Conversations, reactions and characteristics w...               4.0
# 2  It was great that we were able to consolidate ...               2.0
# 3  Customer management used to be done on paper, ...               2.0
# 4  By using Salesforce Sales Cloud, it is no long...               4.0
#
#    rate helpfulness  rate customizability  rate functional satisfaction  \
# 0               4.0                   4.0                           4.0
# 1               4.0                   5.0                           5.0
# 2               3.0                   2.0                           2.0
# 3               4.0                   3.0                           4.0
# 4               5.0                   3.0                           4.0
#
#    rate service stability
# 0                     4.0
# 1                     4.0
# 2                     5.0
# 3                     3.0
# 4                     3.0

# %%
sns.countplot(x='overall rating',alpha=0.7,edgecolor="black", data=df)
sns.despine()
# plt.title("Features : {} ".format(i))

# %%
df.columns
# Out:
# Index(['topic', 'usage situation', 'type of business', 'review date',
#        'overall rating', 'review', 'number of accounts used',
#        'effects after introducing the service', 'rate ease of use',
#        'rate helpfulness', 'rate customizability',
#        'rate functional satisfaction', 'rate service stability'],
#       dtype='object')

# %%
plt.figure(figsize=[15,8])
col=['overall rating', 'rate ease of use',
       'rate helpfulness', 'rate customizability',
       'rate functional satisfaction', 'rate service stability']
n=1
for i in col:
    plt.subplot(2,6,n)
    sns.countplot(x=i,alpha=0.7,edgecolor="black", data=df)
    sns.despine()
    plt.title("{}".format(i))
    n=n+1
plt.tight_layout()
plt.show()

# %%
df['evaluation'] = df['overall rating']

# %%
df['evaluation'] = df['evaluation'].astype(int)

# %%
df.loc[df['evaluation'] < 4, 'evaluation'] = 'low'
df.loc[df['evaluation'] == 5, 'evaluation'] = 'high'
df.loc[df['evaluation'] == 4, 'evaluation'] = 'high'

# %%
df.head()
# Out:
#                                                topic usage situation  \
# 0                      Great job on customer support           using
# 1      You can share customer management in one app.           using
# 2  If you do not spend time consulting at the tim...           using
# 3                      Customer management made easy           using
# 4       Interdepartmental links can be made stronger           using
#
#                     type of business review date  overall rating  \
# 0                 Consulting Service  2022-07-28               4
# 1                 IT related Service  2022-07-28               5
# 2           Food and Leisure Service  2022-07-22               3
# 3                 IT related Service  2022-07-20               4
# 4  Manufacturer/manufacturing system  2022-07-19               5
#
#                                               review number of accounts used  \
# 0  You can manage the history of previous interac...                >201-300
# 1  By collectively managing internal customer inf...                 >51-100
# 2  Consultation at the time of introduction is th...                 >51-100
# 3  With this service, you can manage customer inf...                      >1
# 4  Salesforce Sales Cloud has a very easy-to-read...                    2-10
#
#                effects after introducing the service  rate ease of use  \
# 0  In the past, sales management and personnel ma...               4.0
# 1  Conversations, reactions and characteristics w...               4.0
# 2  It was great that we were able to consolidate ...               2.0
# 3  Customer management used to be done on paper, ...               2.0
# 4  By using Salesforce Sales Cloud, it is no long...               4.0
#
#    rate helpfulness  rate customizability  rate functional satisfaction  \
# 0               4.0                   4.0                           4.0
# 1               4.0                   5.0                           5.0
# 2               3.0                   2.0                           2.0
# 3               4.0                   3.0                           4.0
# 4               5.0                   3.0                           4.0
#
#    rate service stability evaluation
# 0                     4.0       high
# 1                     4.0       high
# 2                     5.0        low
# 3                     3.0       high
# 4                     3.0       high

# %%
df_dum = df[['usage situation', 'type of business', 'overall rating', 'number of accounts used', 'evaluation']]

# %%
df_dum = pd.get_dummies(df_dum, prefix = ['usage', 'b', '#account', 'eval'], 
                   columns = ['usage situation', 'type of business', 'number of accounts used', 'evaluation'] )

# %%
df_dum.columns
# Out:
# Index(['overall rating', 'usage_currently not using', 'usage_using',
#        'b_Consulting Service', 'b_Finance/Insurance',
#        'b_Food and Leisure Service', 'b_IT related Service',
#        'b_Manufacturer/manufacturing system',
#        'b_Mass Media/Advertising/Design/Game/Entertainment', 'b_Medical',
#        'b_Real Estate/Construction/Equipment',
#        'b_Retail/distribution/trading companies',
#        'b_Transportation/Traffic/Logistics/Warehouse system', '#account_2-10',
#        '#account_301-500', '#account_501-1000', '#account_>1',
#        '#account_>1000', '#account_>101-200', '#account_>11-30',
#        '#account_>201-300', '#account_>31-50', '#account_>51-100', 'eval_high',
#        'eval_low'],
#       dtype='object')

# %%
df_dum.drop(columns = ['eval_low'], inplace = True)

# %%
mask = np.zeros_like(df_dum.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)]= True
# Out:
# /var/folders/4g/4qrhhk3j3kv_nf1xv032ysbw0000gn/T/ipykernel_2930/3957212441.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(df_dum.corr(), dtype=np.bool)

# %%
plt.figure(figsize = (30,20))

sns.heatmap(df_dum.corr(), 
            mask = mask,
            annot=True, 
            cmap = 'Pastel1_r',
            vmax=1,
            vmin=-1,
            linewidths=.5,
            robust=True)
# Out:
# <AxesSubplot:>

# %%
# Top correlations
corr_matrix = df_dum.corr()
d_top = corr_matrix['overall rating'].sort_values(ascending=False)
print('Top Correlations are: \n', d_top.head(10))
# Out:
# Top Correlations are:
#  overall rating                                         1.000000
# eval_high                                              0.765938
# usage_using                                            0.125577
# b_Transportation/Traffic/Logistics/Warehouse system    0.114076
# b_IT related Service                                   0.094542
# b_Finance/Insurance                                    0.061115
# #account_>1000                                         0.060815
# b_Retail/distribution/trading companies                0.053452
# #account_>51-100                                       0.049663
# b_Consulting Service                                   0.030281
# Name: overall rating, dtype: float64

# %%
# Bottom correlations
d_down = corr_matrix['overall rating'].sort_values(ascending=True)
print('Top Negative Correlations are: \n', d_down.head(10))
# Out:
# Top Negative Correlations are:
#  b_Mass Media/Advertising/Design/Game/Entertainment   -0.152284
# usage_currently not using                            -0.125577
# b_Real Estate/Construction/Equipment                 -0.088242
# b_Food and Leisure Service                           -0.081052
# #account_>201-300                                    -0.056181
# #account_>31-50                                      -0.044760
# b_Manufacturer/manufacturing system                  -0.039579
# #account_>11-30                                      -0.034624
# #account_501-1000                                    -0.024379
# b_Medical                                            -0.008493
# Name: overall rating, dtype: float64

# %%
corr_matrix = df_dum.corr()
d_top = corr_matrix['eval_high'].sort_values(ascending=False)
print('Top Correlations are: \n', d_top.head(10))
# Out:
# Top Correlations are:
#  eval_high                                              1.000000
# overall rating                                         0.765938
# usage_using                                            0.134733
# b_IT related Service                                   0.117634
# #account_>101-200                                      0.098283
# #account_>1                                            0.061795
# b_Transportation/Traffic/Logistics/Warehouse system    0.040808
# #account_301-500                                       0.029368
# b_Medical                                              0.028796
# #account_>1000                                         0.022602
# Name: eval_high, dtype: float64

# %% [markdown]
# Salesforce cloud has an overeall rating high for companies such as It related service, Finance/Insurance, or Retail/distribution/trading companies.
#
# On the other hand, for companies such as Real Estate/Construction/Equipment, Food and Leisure Service, or Manufacturer/manufacturing system   had a negative correlation to the overall rating.
#
# It seems like Salesforce cloud is more usable for tech related companies.
#
# I will investigate more what are the key causes for the negative correlations for those companies listed above

# %%
df.to_csv('data_cleaned_translated_dummified.csv')

# %%
df.head()
# Out:
#                                                topic usage situation  \
# 0                      Great job on customer support           using
# 1      You can share customer management in one app.           using
# 2  If you do not spend time consulting at the tim...           using
# 3                      Customer management made easy           using
# 4       Interdepartmental links can be made stronger           using
#
#                     type of business review date  overall rating  \
# 0                 Consulting Service  2022-07-28               4
# 1                 IT related Service  2022-07-28               5
# 2           Food and Leisure Service  2022-07-22               3
# 3                 IT related Service  2022-07-20               4
# 4  Manufacturer/manufacturing system  2022-07-19               5
#
#                                               review number of accounts used  \
# 0  You can manage the history of previous interac...                >201-300
# 1  By collectively managing internal customer inf...                 >51-100
# 2  Consultation at the time of introduction is th...                 >51-100
# 3  With this service, you can manage customer inf...                      >1
# 4  Salesforce Sales Cloud has a very easy-to-read...                    2-10
#
#                effects after introducing the service  rate ease of use  \
# 0  In the past, sales management and personnel ma...               4.0
# 1  Conversations, reactions and characteristics w...               4.0
# 2  It was great that we were able to consolidate ...               2.0
# 3  Customer management used to be done on paper, ...               2.0
# 4  By using Salesforce Sales Cloud, it is no long...               4.0
#
#    rate helpfulness  rate customizability  rate functional satisfaction  \
# 0               4.0                   4.0                           4.0
# 1               4.0                   5.0                           5.0
# 2               3.0                   2.0                           2.0
# 3               4.0                   3.0                           4.0
# 4               5.0                   3.0                           4.0
#
#    rate service stability evaluation
# 0                     4.0       high
# 1                     4.0       high
# 2                     5.0        low
# 3                     3.0       high
# 4                     3.0       high

# %%
df['type of business'].unique()
# Out:
# array(['Consulting Service', 'IT related Service',
#        'Food and Leisure Service', 'Manufacturer/manufacturing system',
#        'Real Estate/Construction/Equipment', 'Finance/Insurance',
#        'Mass Media/Advertising/Design/Game/Entertainment',
#        'Transportation/Traffic/Logistics/Warehouse system',
#        'Retail/distribution/trading companies', 'Medical'], dtype=object)

# %%
low_business = df[df['type of business'] == 'Mass Media/Advertising/Design/Game/Entertainment']
low_business['review'].to_csv('test')

# %%
def strings(words = []):
    base = r'^{}'
    expr = '(?=.*{})'
    # words = ['apple', 'banana', 'cat']  # example
    strings = base.format(''.join(expr.format(w) for w in words))
    return strings

# %%
def create_folder(strings):
    data = df[df['review'].str.contains(strings, na=False)]
    data = data['review']
    return data.to_csv(strings)

# %%
create_folder([''])
